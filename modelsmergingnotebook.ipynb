# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/agricultural-hotspot-fapar-rasters-conflict-info/processed_data/processed_df.csv")
display(df.head())
display(df.info())
# Out:
#   iso3  year  month  tavg  tmin  tmax    pres         tsun   prcp  \
# 0  AGO  2021      2  26.6  24.1  30.7  1010.2  13295.02584  753.0
# 1  AGO  2021      3  26.6  24.0  30.3  1009.7  13295.02584  575.4
# 2  AGO  2021      4  27.1  24.4  31.4  1009.7  13295.02584  755.4
# 3  AGO  2021      5  26.9  24.2  30.7  1011.2  13295.02584  201.6
# 4  AGO  2021      6  25.1  22.9  28.4  1012.7  13295.02584   69.0
#
#    conflict_events  conflict_3mo_avg  conflict_6mo_sum  conflict_prev  \
# 0              2.0          2.000000               2.0            0.0
# 1              6.0          7.666667              25.0            3.0
# 2              5.0          7.333333              45.0            8.0
# 3              1.0          4.666667              36.0            6.0
# 4              1.0          2.666667              22.0            3.0
#
#    conflict_spike  conflict_rel  hs_code  hs_name  \
# 0               1       0.36796        1  Hotspot
# 1               0       1.10388        1  Hotspot
# 2               0       0.91990        1  Hotspot
# 3               0       0.18398        1  Hotspot
# 4               0       0.18398        1  Hotspot
#
#                                 processed_image_path  iso3_encoded
# 0  /content/drive/MyDrive/Colab Notebooks/Unilag ...             0
# 1  /content/drive/MyDrive/Colab Notebooks/Unilag ...             0
# 2  /content/drive/MyDrive/Colab Notebooks/Unilag ...             0
# 3  /content/drive/MyDrive/Colab Notebooks/Unilag ...             0
# 4  /content/drive/MyDrive/Colab Notebooks/Unilag ...             0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4188 entries, 0 to 4187
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   iso3                  4188 non-null   object
#  1   year                  4188 non-null   int64
#  2   month                 4188 non-null   int64
#  3   tavg                  4188 non-null   float64
#  4   tmin                  4188 non-null   float64
#  5   tmax                  4188 non-null   float64
#  6   pres                  4188 non-null   float64
#  7   tsun                  4188 non-null   float64
#  8   prcp                  4188 non-null   float64
#  9   conflict_events       4188 non-null   float64
#  10  conflict_3mo_avg      4188 non-null   float64
#  11  conflict_6mo_sum      4188 non-null   float64
#  12  conflict_prev         4188 non-null   float64
#  13  conflict_spike        4188 non-null   int64
#  14  conflict_rel          4188 non-null   float64
#  15  hs_code               4188 non-null   int64
#  16  hs_name               4188 non-null   object
#  17  processed_image_path  4188 non-null   object
#  18  iso3_encoded          4188 non-null   int64
# dtypes: float64(11), int64(5), object(3)
# memory usage: 621.8+ KB
# None

# %%
# Replace the file path prefix
df['processed_image_path'] = df['processed_image_path'].str.replace('/content/drive/MyDrive/Colab Notebooks/Unilag project/fapar_patches_processed/', '/kaggle/input/agricultural-hotspot-fapar-rasters-conflict-info/processed_data/fapar_patches_processed/')

# Drop rows where 'hs_name' is "Not assessed"
df = df[df['hs_name'] != "Not assessed"].copy()

# Set 'hs_code' to 1 for rows where 'hs_name' is "Major hotspot"
df.loc[df['hs_name'] == "Major hotspot", 'hs_code'] = 1

display(df.head())
display(df.info())
# Out:
#   iso3  year  month  tavg  tmin  tmax    pres         tsun   prcp  \
# 0  AGO  2021      2  26.6  24.1  30.7  1010.2  13295.02584  753.0
# 1  AGO  2021      3  26.6  24.0  30.3  1009.7  13295.02584  575.4
# 2  AGO  2021      4  27.1  24.4  31.4  1009.7  13295.02584  755.4
# 3  AGO  2021      5  26.9  24.2  30.7  1011.2  13295.02584  201.6
# 4  AGO  2021      6  25.1  22.9  28.4  1012.7  13295.02584   69.0
#
#    conflict_events  conflict_3mo_avg  conflict_6mo_sum  conflict_prev  \
# 0              2.0          2.000000               2.0            0.0
# 1              6.0          7.666667              25.0            3.0
# 2              5.0          7.333333              45.0            8.0
# 3              1.0          4.666667              36.0            6.0
# 4              1.0          2.666667              22.0            3.0
#
#    conflict_spike  conflict_rel  hs_code  hs_name  \
# 0               1       0.36796        1  Hotspot
# 1               0       1.10388        1  Hotspot
# 2               0       0.91990        1  Hotspot
# 3               0       0.18398        1  Hotspot
# 4               0       0.18398        1  Hotspot
#
#                                 processed_image_path  iso3_encoded
# 0  /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 1  /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 2  /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 3  /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 4  /kaggle/input/agricultural-hotspot-fapar-raste...             0
# <class 'pandas.core.frame.DataFrame'>
# Index: 4110 entries, 0 to 4187
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   iso3                  4110 non-null   object
#  1   year                  4110 non-null   int64
#  2   month                 4110 non-null   int64
#  3   tavg                  4110 non-null   float64
#  4   tmin                  4110 non-null   float64
#  5   tmax                  4110 non-null   float64
#  6   pres                  4110 non-null   float64
#  7   tsun                  4110 non-null   float64
#  8   prcp                  4110 non-null   float64
#  9   conflict_events       4110 non-null   float64
#  10  conflict_3mo_avg      4110 non-null   float64
#  11  conflict_6mo_sum      4110 non-null   float64
#  12  conflict_prev         4110 non-null   float64
#  13  conflict_spike        4110 non-null   int64
#  14  conflict_rel          4110 non-null   float64
#  15  hs_code               4110 non-null   int64
#  16  hs_name               4110 non-null   object
#  17  processed_image_path  4110 non-null   object
#  18  iso3_encoded          4110 non-null   int64
# dtypes: float64(11), int64(5), object(3)
# memory usage: 642.2+ KB
# None

# %%
def create_time_series_splits(df, n_steps, val_test_split_ratio):
    """
    Creates time series sequences and splits data into training, validation, and test sets
    per country.

    Args:
        df (pd.DataFrame): The input DataFrame with time series data and 'iso3' column.
        n_steps (int): The number of time steps in each input sequence (X).
        val_test_split_ratio (float): The combined proportion of data for validation and testing.

    Returns:
        tuple: A tuple containing X_train, y_train, X_val, y_val, X_test, y_test.
               Returns (None, None, None, None, None, None) if processing fails or no data.
    """
    all_X_train, all_y_train = [], []
    all_X_val, all_y_val = [], []
    all_X_test, all_y_test = [], []

    # Group by country
    grouped_data = df.groupby('iso3')

    for iso3, country_df in grouped_data:
        # Sort data chronologically
        country_df = country_df.sort_values(by=['year', 'month'])
        numeric_cols = country_df.select_dtypes(include=np.number).columns.tolist()
        country_data = country_df[numeric_cols].values

        # Check if there's enough data to create at least one sequence for train, val, and test
        required_length = n_steps + 1  # n_steps for X, 1 for y
        if len(country_data) < required_length + int(len(country_data) * val_test_split_ratio):
            print(f"Skipping country {iso3}: Insufficient data ({len(country_data)} rows) to create sequences and splits with n_steps={n_steps} and val_test_split_ratio={val_test_split_ratio}.")
            continue

        # Create time series sequences
        X, y = [], []
        for i in range(len(country_data) - n_steps):
            # Create input sequence (X)
            seq_x = country_data[i:(i + n_steps)]
            X.append(seq_x)
            seq_y = country_data[i + n_steps]
            y.append(seq_y)

        X = np.array(X)
        y = np.array(y)

        # Determine split points
        num_sequences = len(X)
        if num_sequences == 0:
             print(f"Skipping country {iso3}: No sequences could be created with n_steps={n_steps}.")
             continue

        val_test_size = int(num_sequences * val_test_split_ratio)
        test_size = val_test_size // 2
        val_size = val_test_size - test_size
        train_size = num_sequences - val_test_size

        if train_size <= 0:
             print(f"Skipping country {iso3}: Not enough sequences ({num_sequences}) for training with val_test_split_ratio={val_test_split_ratio}.")
             continue


        # Split data chronologically
        X_train = X[:train_size]
        y_train = y[:train_size]
        X_val = X[train_size:(train_size + val_size)]
        y_val = y[train_size:(train_size + val_size)]
        X_test = X[(train_size + val_size):]
        y_test = y[(train_size + val_size):]

        all_X_train.append(X_train)
        all_y_train.append(y_train)
        all_X_val.append(X_val)
        all_y_val.append(y_val)
        all_X_test.append(X_test)
        all_y_test.append(y_test)

    # Concatenate data from all countries
    if not all_X_train: # Check if any training data was generated
        print("No training data generated for any country.")
        return None, None, None, None, None, None

    X_train_combined = np.concatenate(all_X_train, axis=0)
    y_train_combined = np.concatenate(all_y_train, axis=0)
    X_val_combined = np.concatenate(all_X_val, axis=0) if all_X_val else np.array([])
    y_val_combined = np.concatenate(all_y_val, axis=0) if all_y_val else np.array([])
    X_test_combined = np.concatenate(all_X_test, axis=0) if all_X_test else np.array([])
    y_test_combined = np.concatenate(all_y_test, axis=0) if all_y_test else np.array([])


    return X_train_combined, y_train_combined, X_val_combined, y_val_combined, X_test_combined, y_test_combined

# %%
import pandas as pd

def split_dataframe_chronologically_by_country(df, val_test_split_ratio):
    """
    Splits a DataFrame into training, validation, and test sets chronologically
    per country.

    Args:
        df (pd.DataFrame): The input DataFrame with time series data and 'iso3' column.
        val_test_split_ratio (float): The combined proportion of data for validation and testing.

    Returns:
        tuple: A tuple containing train_df, val_df, test_df.
               Returns (pd.DataFrame(), pd.DataFrame(), pd.DataFrame()) if no data.
    """
    all_train_dfs, all_val_dfs, all_test_dfs = [], [], []

    # Group by country
    grouped_data = df.groupby('iso3')

    for iso3, country_df in grouped_data:
        # Sort data chronologically
        country_df = country_df.sort_values(by=['year', 'month']).reset_index(drop=True)

        num_rows = len(country_df)

        # Determine split points
        val_test_size = int(num_rows * val_test_split_ratio)
        test_size = val_test_size // 2
        val_size = val_test_size - test_size
        train_size = num_rows - val_test_size

        if train_size <= 0:
             print(f"Skipping country {iso3}: Not enough data ({num_rows} rows) for training after split with val_test_split_ratio={val_test_split_ratio}.")
             continue

        # Split data chronologically
        train_df_country = country_df.iloc[:train_size].copy()
        val_df_country = country_df.iloc[train_size:(train_size + val_size)].copy()
        test_df_country = country_df.iloc[(train_size + val_size):].copy()

        all_train_dfs.append(train_df_country)
        all_val_dfs.append(val_df_country)
        all_test_dfs.append(test_df_country)

    # Concatenate dataframes from all countries
    train_df_combined = pd.concat(all_train_dfs, ignore_index=True) if all_train_dfs else pd.DataFrame()
    val_df_combined = pd.concat(all_val_dfs, ignore_index=True) if all_val_dfs else pd.DataFrame()
    test_df_combined = pd.concat(all_test_dfs, ignore_index=True) if all_test_dfs else pd.DataFrame()


    return train_df_combined, val_df_combined, test_df_combined

# %%
# Define split ratio and parameters for Dataset and DataLoader
val_test_split_ratio = 0.3
n_steps_for_dataloader = 6
forecast_horizon = 3
output_dir = "/content/fapar_patches_processed"
batch_size = 32
num_workers = 2
target_col = 'hs_code'

# Split the DataFrame chronologically by country
train_df, val_df, test_df = split_dataframe_chronologically_by_country(df, val_test_split_ratio)

# %%
train_df
# Out:
#      iso3  year  month  tavg  tmin  tmax    pres         tsun   prcp  \
# 0     AGO  2021      2  26.6  24.1  30.7  1010.2  13295.02584  753.0
# 1     AGO  2021      3  26.6  24.0  30.3  1009.7  13295.02584  575.4
# 2     AGO  2021      4  27.1  24.4  31.4  1009.7  13295.02584  755.4
# 3     AGO  2021      5  26.9  24.2  30.7  1011.2  13295.02584  201.6
# 4     AGO  2021      6  25.1  22.9  28.4  1012.7  13295.02584   69.0
# ...   ...   ...    ...   ...   ...   ...     ...          ...    ...
# 2908  ZWE  2023      8  22.9  17.9  28.9  1018.5  13295.02584    0.0
# 2909  ZWE  2023      9  27.3  21.6  33.8  1012.5  13295.02584    0.0
# 2910  ZWE  2023     10  30.5  25.3  36.4  1010.0  13295.02584    4.5
# 2911  ZWE  2023     11  31.0  26.4  36.4  1009.9  13295.02584   16.2
# 2912  ZWE  2023     12  28.9  25.2  33.2  1009.8  13295.02584  467.1
#
#       conflict_events  conflict_3mo_avg  conflict_6mo_sum  conflict_prev  \
# 0                 2.0          2.000000               2.0            0.0
# 1                 6.0          7.666667              25.0            3.0
# 2                 5.0          7.333333              45.0            8.0
# 3                 1.0          4.666667              36.0            6.0
# 4                 1.0          2.666667              22.0            3.0
# ...               ...               ...               ...            ...
# 2908             27.0         22.333333             115.0           38.0
# 2909             18.0         16.000000             115.0           29.0
# 2910              9.0         10.333333              79.0           19.0
# 2911              8.0          6.666667              51.0           10.0
# 2912              5.0          5.666667              37.0            8.0
#
#       conflict_spike  conflict_rel  hs_code     hs_name  \
# 0                  1      0.367960        1     Hotspot
# 1                  0      1.103880        1     Hotspot
# 2                  0      0.919900        1     Hotspot
# 3                  0      0.183980        1     Hotspot
# 4                  0      0.183980        1     Hotspot
# ...              ...           ...      ...         ...
# 2908               0      3.911468        0  No hotspot
# 2909               0      2.607645        0  No hotspot
# 2910               0      1.303823        0  No hotspot
# 2911               0      1.158954        0  No hotspot
# 2912               0      0.724346        0  No hotspot
#
#                                    processed_image_path  iso3_encoded
# 0     /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 1     /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 2     /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 3     /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 4     /kaggle/input/agricultural-hotspot-fapar-raste...             0
# ...                                                 ...           ...
# 2908  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 2909  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 2910  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 2911  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 2912  /kaggle/input/agricultural-hotspot-fapar-raste...            61
#
# [2913 rows x 19 columns]

# %%
val_df
# Out:
#     iso3  year  month  tavg  tmin  tmax    pres         tsun   prcp  \
# 0    AGO  2024      2  28.1  25.1  31.9  1010.7  13295.02584  699.0
# 1    AGO  2024      3  28.6  25.7  32.2  1009.7  13295.02584  840.6
# 2    AGO  2024      4  28.2  25.4  32.1  1009.3  13295.02584  498.0
# 3    AGO  2024      5  27.9  25.7  31.4  1010.5  13295.02584  150.6
# 4    AGO  2024      6  24.8  22.3  28.2  1013.4  13295.02584   17.7
# ..   ...   ...    ...   ...   ...   ...     ...          ...    ...
# 605  ZWE  2024      3  29.1  25.4  33.2  1012.1  13295.02584   19.2
# 606  ZWE  2024      4  26.0  22.7  29.9  1014.2  13295.02584  124.5
# 607  ZWE  2024      5  24.1  19.7  29.1  1017.4  13295.02584    0.0
# 608  ZWE  2024      6  21.8  17.3  26.9  1019.7  13295.02584    7.5
# 609  ZWE  2024      7  21.8  16.2  28.4  1017.4  13295.02584    0.0
#
#      conflict_events  conflict_3mo_avg  conflict_6mo_sum  conflict_prev  \
# 0                1.0          3.666667              17.0            3.0
# 1                3.0          2.000000              17.0            2.0
# 2                5.0          4.000000              18.0            3.0
# 3                5.0          5.333333              28.0            7.0
# 4                8.0          5.333333              32.0            8.0
# ..               ...               ...               ...            ...
# 605              4.0          4.666667              28.0            6.0
# 606              3.0          4.666667              28.0            5.0
# 607              2.0          1.666667              19.0            3.0
# 608              3.0          2.666667              13.0            2.0
# 609              4.0          4.000000              20.0            6.0
#
#      conflict_spike  conflict_rel  hs_code        hs_name  \
# 0                 0      0.183980        0     No hotspot
# 1                 0      0.551940        0     No hotspot
# 2                 0      0.919900        0     No hotspot
# 3                 0      0.919900        0     No hotspot
# 4                 0      1.471840        0     No hotspot
# ..              ...           ...      ...            ...
# 605               0      0.579477        1  Major hotspot
# 606               0      0.434608        1  Major hotspot
# 607               0      0.289738        1  Major hotspot
# 608               0      0.434608        1  Major hotspot
# 609               0      0.579477        1  Major hotspot
#
#                                   processed_image_path  iso3_encoded
# 0    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 1    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 2    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 3    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 4    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# ..                                                 ...           ...
# 605  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 606  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 607  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 608  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 609  /kaggle/input/agricultural-hotspot-fapar-raste...            61
#
# [610 rows x 19 columns]

# %%
test_df
# Out:
#     iso3  year  month  tavg  tmin  tmax    pres         tsun   prcp  \
# 0    AGO  2024     11  26.5  24.1  29.4  1011.2  13295.02584  837.3
# 1    AGO  2025      1  26.7  24.3  29.7  1010.8  13295.02584  471.0
# 2    AGO  2025      2  26.5  24.2  29.6  1009.8  13295.02584  608.1
# 3    AGO  2025      4  26.8  24.4  32.7  1010.1  13295.02584  386.4
# 4    AGO  2025      5  25.9  23.9  29.6  1012.0  13295.02584  513.9
# ..   ...   ...    ...   ...   ...   ...     ...          ...    ...
# 582  ZWE  2025      1  26.2  23.6  29.1  1009.2  13295.02584  990.0
# 583  ZWE  2025      2  26.9  24.2  30.0  1009.3  13295.02584  805.2
# 584  ZWE  2025      5  22.8  19.4  26.8  1018.7  13295.02584   12.3
# 585  ZWE  2025      6  20.6  16.6  25.5  1019.9  13295.02584    0.0
# 586  ZWE  2025      7  20.4  16.3  25.3  1021.6  13295.02584    0.3
#
#      conflict_events  conflict_3mo_avg  conflict_6mo_sum  conflict_prev  \
# 0                0.0          0.666667               7.0            0.0
# 1                2.0          2.000000               8.0            0.0
# 2                3.0          2.000000              12.0            3.0
# 3                2.0          2.333333              13.0            3.0
# 4                3.0          3.333333              17.0            3.0
# ..               ...               ...               ...            ...
# 582              2.0          2.000000              14.0            2.0
# 583              0.0          1.333333              10.0            2.0
# 584              2.0          0.666667               6.0            0.0
# 585              2.0          2.333333               9.0            2.0
# 586              0.0          1.000000              10.0            2.0
#
#      conflict_spike  conflict_rel  hs_code     hs_name  \
# 0                 0      0.000000        0  No hotspot
# 1                 1      0.367960        0  No hotspot
# 2                 0      0.551940        0  No hotspot
# 3                 0      0.367960        0  No hotspot
# 4                 0      0.551940        0  No hotspot
# ..              ...           ...      ...         ...
# 582               0      0.289738        1     Hotspot
# 583               0      0.000000        0  No hotspot
# 584               1      0.289738        0  No hotspot
# 585               0      0.289738        0  No hotspot
# 586               0      0.000000        0  No hotspot
#
#                                   processed_image_path  iso3_encoded
# 0    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 1    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 2    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 3    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# 4    /kaggle/input/agricultural-hotspot-fapar-raste...             0
# ..                                                 ...           ...
# 582  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 583  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 584  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 585  /kaggle/input/agricultural-hotspot-fapar-raste...            61
# 586  /kaggle/input/agricultural-hotspot-fapar-raste...            61
#
# [587 rows x 19 columns]

# %%
print(f"Train DataFrame shape: {train_df.shape}")
print(f"Validation DataFrame shape: {val_df.shape}")
print(f"Test DataFrame shape: {test_df.shape}")
# Out:
# Train DataFrame shape: (2913, 19)
# Validation DataFrame shape: (610, 19)
# Test DataFrame shape: (587, 19)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import tifffile
import os
import cv2 # Using OpenCV for resizing and padding

class ConflictDataset(Dataset):
    """Custom Dataset for loading processed FAPAR images and numerical data for multi-step forecasting."""

    def __init__(self, dataframe, img_dir, n_steps, forecast_horizon, target_col='hs_code', target_size=(256, 256)):
        """
        Args:
            dataframe (pd.DataFrame): DataFrame containing numerical features and image paths.
            img_dir (str): Directory with processed image files.
            n_steps (int): Number of time steps in the input sequence (X).
            forecast_horizon (int): The number of future time steps to forecast.
            target_col (str): The name of the target column in the DataFrame. Defaults to 'hs_code'.
            target_size (tuple): The target spatial size (height, width) for image resizing. Defaults to (256, 256).
        """
        self.dataframe = dataframe.copy()
        self.img_dir = img_dir
        self.n_steps = n_steps
        self.forecast_horizon = forecast_horizon
        self.target_col = target_col
        self.target_size = target_size # (height, width)

        # Pre-process the DataFrame to create sequences and store image paths, multi-step numerical targets, and classification targets
        self.sequences = []
        self.image_paths = []
        self.numerical_targets = [] # Targets for numerical feature prediction
        self.classification_targets = [] # Targets for classification
        self.indices = [] # Store original DataFrame index for potential debugging or joining later
        self.target_image_paths = []


        # Ensure DataFrame is sorted by country, year, and month
        self.dataframe = self.dataframe.sort_values(by=['iso3', 'year', 'month']).reset_index(drop=True)

        # Group by country
        grouped_data = self.dataframe.groupby('iso3')

        for iso3, country_df in grouped_data:
            # Determine numerical feature columns excluding 'year' and 'target_col' for the input sequence
            numerical_feature_cols_input = [col for col in country_df.select_dtypes(include=np.number).columns.tolist() if col not in ['year', self.target_col]]

            # Determine numerical feature columns for the numerical target sequence
            # This should match the features the forecast model is predicting.
            # Based on ModelTrainer, this is numerical_feature_cols, which excludes 'year' and 'target_col'
            numerical_feature_cols_target = [col for col in country_df.select_dtypes(include=np.number).columns.tolist() if col not in ['year', self.target_col]]


            country_features_input = country_df[numerical_feature_cols_input].values
            country_numerical_targets_data = country_df[numerical_feature_cols_target].values # Use the filtered list for targets
            country_classification_targets_data = country_df[self.target_col].values
            country_image_paths = country_df['processed_image_path'].values
            country_indices = country_df.index.values # Original indices in the sorted df


            # Create time series sequences with multi-step targets
            # We need enough data for the input sequence (n_steps) PLUS the forecast horizon
            for i in range(len(country_df) - self.n_steps - self.forecast_horizon + 1):
                # Numerical sequence (X)
                seq_x = country_features_input[i:(i + self.n_steps)]
                self.sequences.append(seq_x)

                # Image paths for the sequence (X) - we need n_steps images
                seq_img_paths = country_image_paths[i:(i + self.n_steps)]
                self.image_paths.append(seq_img_paths)

                # Multi-step numerical targets (y_num)
                # Starting from the step immediately following the input sequence
                seq_y_num = country_numerical_targets_data[(i + self.n_steps):(i + self.n_steps + self.forecast_horizon)]
                self.numerical_targets.append(seq_y_num)

                self.target_image_paths.append(country_image_paths[(i + self.n_steps):(i + self.n_steps + self.forecast_horizon)])

                # Multi-step classification targets (y_cls)
                seq_y_cls = country_classification_targets_data[(i + self.n_steps):(i + self.n_steps + self.forecast_horizon)]
                self.classification_targets.append(seq_y_cls)


                # Store the index of the first target element in the original sorted df
                self.indices.append(country_indices[i + self.n_steps])


        self.sequences = np.array(self.sequences)
        # image_paths are already a list of numpy arrays/lists
        self.numerical_targets = np.array(self.numerical_targets)
        self.classification_targets = np.array(self.classification_targets)
        self.indices = np.array(self.indices)


    def __len__(self):
        """Returns the number of samples in the dataset."""
        return len(self.sequences)

    def __getitem__(self, idx):
        """Retrieves a sample (sequence of numerical features, sequence of images, multi-step numerical target, multi-step classification target) at the given index."""
        if torch.is_tensor(idx):
            idx = idx.tolist()

        # Get the numerical sequence and targets
        numerical_sequence = self.sequences[idx]
        numerical_target = self.numerical_targets[idx]
        classification_target = self.classification_targets[idx]
        original_index = self.indices[idx]


        # Load and process the corresponding image sequence
        processed_image_sequence = []
        for img_filename in self.image_paths[idx]:
            img_path = img_filename # img_filename already contains the full path after previous processing steps
            try:
                # Load image using tifffile
                img = tifffile.imread(img_path)
                img = np.nan_to_num(img, nan=0) # Handle potential NaN values

                # Resize image directly to the target size
                # original_height, original_width = img.shape[:2]
                target_height, target_width = self.target_size
                # Resize using OpenCV (handles grayscale and color images correctly)
                # Target size is (width, height) for cv2.resize
                processed_img = cv2.resize(img, (target_width, target_height), interpolation=cv2.INTER_AREA)
                processed_img = np.mean(processed_img, axis = -1)


                processed_image_sequence.append(processed_img)

            except FileNotFoundError:
                print(f"Warning: Image file not found at {img_path}. Returning zero array for this image.")
                # Return a zero array with the target size and channel count if image is not found
                # Assuming 3 channels for consistency if original images are color, otherwise 1
                channels = processed_image_sequence[0].shape[-1] if processed_image_sequence else (img.shape[-1] if img.ndim == 3 else 1)
                processed_image_sequence.append(np.zeros(self.target_size + (channels,), dtype=np.float32))

            except Exception as e:
                print(f"Error loading or processing image {img_path}: {e}. Returning zero array for this image.")
                # Return a zero array with the target size and channel count on other errors
                channels = processed_image_sequence[0].shape[-1] if processed_image_sequence else (img.shape[-1] if img.ndim == 3 else 1)
                processed_image_sequence.append(np.zeros(self.target_size + (channels,), dtype=np.float32))



        # Stack processed images along the time step dimension (axis=0)
        # Resulting shape will be (n_steps, height, width, channels)
        image_sequence_stacked = np.stack(processed_image_sequence, axis=0)

        # Load and process the corresponding image sequence
        target_processed_image_sequence = []
        for img_filename in self.target_image_paths[idx]:
            img_path = img_filename # img_filename already contains the full path after previous processing steps
            try:
                # Load image using tifffile
                img = tifffile.imread(img_path)
                img = np.nan_to_num(img, nan=0) # Handle potential NaN values

                # Resize image directly to the target size
                # original_height, original_width = img.shape[:2]
                target_height, target_width = self.target_size

                # Resize using OpenCV (handles grayscale and color images correctly)
                # Target size is (width, height) for cv2.resize
                processed_img = cv2.resize(img, (target_width, target_height), interpolation=cv2.INTER_AREA)
                processed_img = np.mean(processed_img, axis = -1)

                target_processed_image_sequence.append(processed_img)

            except FileNotFoundError:
                print(f"Warning: Image file not found at {img_path}. Returning zero array for this image.")
                # Return a zero array with the target size and channel count if image is not found
                # Assuming 3 channels for consistency if original images are color, otherwise 1
                channels = processed_image_sequence[0].shape[-1] if processed_image_sequence else (img.shape[-1] if img.ndim == 3 else 1)
                processed_image_sequence.append(np.zeros(self.target_size + (channels,), dtype=np.float32))

            except Exception as e:
                print(f"Error loading or processing image {img_path}: {e}. Returning zero array for this image.")
                # Return a zero array with the target size and channel count on other errors
                channels = processed_image_sequence[0].shape[-1] if processed_image_sequence else (img.shape[-1] if img.ndim == 3 else 1)
                target_processed_image_sequence.append(np.zeros(self.target_size + (channels,), dtype=np.float32))
                


        # Stack processed images along the time step dimension (axis=0)
        # Resulting shape will be (n_steps, height, width, channels)
        target_processed_image_sequence_stacked = np.stack(target_processed_image_sequence, axis=0)


        # Convert numpy arrays to PyTorch tensors
        numerical_sequence_tensor = np.array(numerical_sequence, dtype=np.float32)
        image_sequence_tensor = np.array(image_sequence_stacked, dtype=np.float32)
        target_image_sequence_tensor = np.array(target_processed_image_sequence_stacked, dtype=np.float32)
        numerical_target_tensor = np.array(numerical_target, dtype=np.float32)
        classification_target_tensor = np.array(classification_target, dtype=np.uint8) # Classification targets are usually LongTensors

        return numerical_sequence_tensor, image_sequence_tensor, numerical_target_tensor, target_image_sequence_tensor, classification_target_tensor, original_index

# %%
import tensorflow as tf
import gc
train_dataset = ConflictDataset(train_df, output_dir,
                                5, 2, target_col='hs_code', target_size=(64,64))
# Convert PyTorch data to NumPy arrays (or other compatible format)
num_seqs, im_seqs, num_targets, im_targets, target_cls = [], [], [], [], []
for num_seq, im_seq, num_target, im_target, target_ls, _ in train_dataset:
    num_seqs.append(num_seq)
    im_seqs.append(im_seq)
    num_targets.append(num_target)
    im_targets.append(im_target)
    target_cls.append(target_ls)

train_images = np.array(im_seqs)
train_features = np.array(num_seqs)
train_target_images = np.array(im_targets)
train_target_features = np.array(num_targets)
train_classes = np.array(target_cls)

del num_seqs, im_seqs, num_targets, im_targets, target_cls
gc.collect()
# Out:
# 2025-09-28 14:02:44.825838: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759068164.992412      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759068165.041175      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 3585

# %%
val_dataset = ConflictDataset(val_df, output_dir,
                                5, 2, target_col='hs_code', target_size=(64,64))
# Convert PyTorch data to NumPy arrays (or other compatible format)
num_seqs, im_seqs, num_targets, im_targets, target_cls = [], [], [], [], []
for num_seq, im_seq, num_target, im_target, target_ls, _ in val_dataset:
    num_seqs.append(num_seq)
    im_seqs.append(im_seq)
    num_targets.append(num_target)
    im_targets.append(im_target)
    target_cls.append(target_ls)

val_images = np.array(im_seqs)
val_features = np.array(num_seqs)
val_target_images = np.array(im_targets)
val_target_features = np.array(num_targets)
val_classes = np.array(target_cls)

del num_seqs, im_seqs, num_targets, im_targets, target_cls
gc.collect()
# Out:
# 1269

# %%
test_dataset = ConflictDataset(test_df, output_dir,
                                5, 2, target_col='hs_code', target_size=(64,64))
# Convert PyTorch data to NumPy arrays (or other compatible format)
num_seqs, im_seqs, num_targets, im_targets, target_cls = [], [], [], [], []
for num_seq, im_seq, num_target, im_target, target_ls, _ in test_dataset:
    num_seqs.append(num_seq)
    im_seqs.append(im_seq)
    num_targets.append(num_target)
    im_targets.append(im_target)
    target_cls.append(target_ls)

test_images = np.array(im_seqs)
test_features = np.array(num_seqs)
test_target_images = np.array(im_targets)
test_target_features = np.array(num_targets)
test_classes = np.array(target_cls)

del num_seqs, im_seqs, num_targets, im_targets, target_cls
gc.collect()
# Out:
# 929

# %%
train_images.shape, test_images.shape, val_images.shape
# Out:
# ((2542, 5, 64, 64), (253, 5, 64, 64), (268, 5, 64, 64))

# %%
train_features.shape, test_features.shape, val_features.shape
# Out:
# ((2542, 5, 14), (253, 5, 14), (268, 5, 14))

# %%
train_target_images.shape, test_target_images.shape, val_target_images.shape
# Out:
# ((2542, 2, 64, 64), (253, 2, 64, 64), (268, 2, 64, 64))

# %%
train_images = train_images.transpose((0,2,3,1))
val_images = val_images.transpose((0,2,3,1))
test_images = test_images.transpose((0,2,3,1))
print(train_images.shape)
print(val_images.shape)
print(test_images.shape)
# Out:
# (2542, 64, 64, 5)
# (268, 64, 64, 5)
# (253, 64, 64, 5)

# %%
train_target_images = train_target_images.transpose((0,2,3,1))
val_target_images = val_target_images.transpose((0,2,3,1))
test_target_images = test_target_images.transpose((0,2,3,1))
print(train_target_images.shape)
print(val_target_images.shape)
print(test_target_images.shape)
# Out:
# (2542, 64, 64, 2)
# (268, 64, 64, 2)
# (253, 64, 64, 2)

# %%
import keras
modelRasterForecast = keras.models.load_model("/kaggle/input/agricultural-hotspot-fapar-rasters-conflict-info/imForeCastRMSPROP-NO-ACTIVATION.keras")
# Out:
# I0000 00:00:1759068241.143701      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
modelRasterForecast.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 5) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 64, 4) │        184 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64, 4) │        148 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 32, 4) │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32, 8) │        296 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32, 8) │        584 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 16, 16, 8) │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │      1,168 │ max_pooling2d_1[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 16,    │      2,320 │ conv2d_4[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 8, 8, 16)  │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 32)  │      4,640 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 8, 32)  │      9,248 │ conv2d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 4, 4, 32)  │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 4, 4, 64)  │     18,496 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 4, 4, 64)  │     36,928 │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 2, 2, 64)  │          0 │ conv2d_9[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 2, 2, 128) │     73,856 │ max_pooling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 2, 2, 128) │    147,584 │ conv2d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 4, 4, 64)  │     32,832 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 4, 4, 128) │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 4, 4, 64)  │     73,792 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 4, 4, 64)  │     73,792 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 4, 4, 64)  │     36,928 │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 4, 4, 64)  │     36,928 │ conv2d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 8, 8, 32)  │      8,224 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 8, 8, 32)  │      8,224 │ conv2d_23[0][0]   │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 8, 8, 64)  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 8, 8, 64)  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 8, 8, 32)  │     18,464 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ concatenate_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 8, 8, 32)  │      9,248 │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ conv2d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 16, 16,    │      2,064 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 16, 16,    │      8,224 │ conv2d_25[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 48)               │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │      4,624 │ concatenate_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 16, 16,    │     27,712 │ concatenate_6[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │      2,320 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 16, 16,    │     36,928 │ conv2d_26[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 32, 32, 8) │        520 │ conv2d_17[0][0]   │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 32, 32,    │      8,224 │ conv2d_27[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 16)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 40)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 32, 32, 8) │      1,160 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 32, 32,    │     23,104 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32, 8) │        584 │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 32, 32,    │     36,928 │ conv2d_28[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 64, 64, 4) │        132 │ conv2d_19[0][0]   │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 64, 64,    │      8,224 │ conv2d_29[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 64, 64, 8) │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 36)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 64, 64, 8) │        584 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 64, 64,    │     20,800 │ concatenate_8[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 64, 64, 8) │        584 │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 64, 64,    │     36,928 │ conv2d_30[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ year1 (Conv2D)      │ (None, 64, 64, 1) │          9 │ conv2d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ year2 (Conv2D)      │ (None, 64, 64, 1) │         65 │ conv2d_31[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,774,918 (6.77 MB)
#  Trainable params: 887,458 (3.39 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 887,460 (3.39 MB)

# %%
modelTabularForecast = keras.models.load_model("/kaggle/input/agricultural-hotspot-fapar-rasters-conflict-info/featuresModel.keras")
modelTabularForecast.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 70)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 70)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 300)            │        21,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 150)            │        45,150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         9,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 28)             │         1,820 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 155,870 (608.87 KB)
#  Trainable params: 77,934 (304.43 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 77,936 (304.44 KB)

# %%
classifierModelY1 = keras.models.load_model('/kaggle/input/lastclassifierattempt1c/lastClassifier1C_f.keras')
classifierModelY1.summary()
# Out:
# Model: "final_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 14)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model1 (Functional) │ (None, 1)         │  1,260,223 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model2 (Functional) │ (None, 1)         │  1,283,981 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model3 (Functional) │ (None, 1)         │  2,203,951 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model4 (Functional) │ (None, 1)         │  2,203,951 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model5 (Functional) │ (None, 1)         │  2,263,969 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 19)        │          0 │ input_layer_1[0]… │
# │ (Concatenate)       │                   │            │ model1[0][0],     │
# │                     │                   │            │ model2[0][0],     │
# │                     │                   │            │ model3[0][0],     │
# │                     │                   │            │ model4[0][0],     │
# │                     │                   │            │ model5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │      2,560 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 27,656,294 (105.50 MB)
#  Trainable params: 9,218,764 (35.17 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 18,437,530 (70.33 MB)

# %%
classifierModelY2 = keras.models.load_model('/kaggle/input/lastclassifierattempt1c/lastClassifier1C_f.keras')
classifierModelY2.summary()
# Out:
# Model: "final_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 14)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model1 (Functional) │ (None, 1)         │  1,260,223 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model2 (Functional) │ (None, 1)         │  1,283,981 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model3 (Functional) │ (None, 1)         │  2,203,951 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model4 (Functional) │ (None, 1)         │  2,203,951 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ model5 (Functional) │ (None, 1)         │  2,263,969 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 19)        │          0 │ input_layer_1[0]… │
# │ (Concatenate)       │                   │            │ model1[0][0],     │
# │                     │                   │            │ model2[0][0],     │
# │                     │                   │            │ model3[0][0],     │
# │                     │                   │            │ model4[0][0],     │
# │                     │                   │            │ model5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │      2,560 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 27,656,294 (105.50 MB)
#  Trainable params: 9,218,764 (35.17 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 18,437,530 (70.33 MB)

# %%
from tensorflow.keras.layers import Dense, Lambda

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Lambda, Dense, Layer
from tensorflow.keras.models import Model

def split_y1(x):
    return x[:, :14]
def split_y2(x):
    return x[:, 14:]

def forecastClassifierModel():
    # Inputs
    imageInput = keras.layers.Input((64, 64, 5), name="image_input")
    tabularInput = keras.layers.Input((70,), name='tabular_input')
    m1 = modelRasterForecast
    m1.name = "RasterForecastModel"
    m2 = modelTabularForecast
    m2.name = "TabularForecastModel"
    m3 = classifierModelY1
    m3.name = "Year1Classifier" #has both prediction from image and tabular data embedded
    m4 = classifierModelY2
    m4.name = "Year2Classifier" #has both prediction from image and tabular data embed
    
    # --- Feature Extraction ---
    outImage1_raw, outImage2_raw = m1(imageInput)
    tabularForecast_raw = m2(tabularInput)

    # --- Stable Naming for Image Outputs ---
    outImage1 = keras.layers.Activation('linear', name='raster_output_Y1')(outImage1_raw)
    outImage2 = keras.layers.Activation('linear', name='raster_output_Y2')(outImage2_raw)

    # --- Tabular Split (Lambda layers already have stable names) ---
    tabularForecastY1 = Lambda(split_y1, name='tabularForecastY1')(tabularForecast_raw)
    tabularForecastY2 = Lambda(split_y2, name='tabularForecastY2')(tabularForecast_raw)

    # --- Final Classifier Outputs (These layers already have stable names) ---
    year1Class = m3(
        (outImage1, tabularForecastY1)
    )  # Assumes classifierModelY1 accepts a tuple of tensors
    year2Class = m4(
        (outImage2, tabularForecastY2)
    ) # Assumes classifierModelY2 accepts a tuple of tensors

    # --- Final Model Construction ---
    model = keras.models.Model(
        inputs=[imageInput, tabularInput], 
        outputs=[
            outImage1, outImage2,  # Image Forecast Outputs
            tabularForecastY1, tabularForecastY2, # Tabular Forecast Outputs
            year1Class, year2Class # Classifier Outputs
        ], 
        name="FINAL-FORECAST-CLASSIFIER-MODEL"
    )
    return model

# 2. Build and Compile the Model
model = forecastClassifierModel()

# %%
model.summary()
# Out:
# Model: "FINAL-FORECAST-CLASSIFIER-MODEL"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 64, 64, 5) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabular_input       │ (None, 70)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ RasterForecastModel │ [(None, 64, 64,   │    887,458 │ image_input[0][0] │
# │ (Functional)        │ 1), (None, 64,    │            │                   │
# │                     │ 64, 1)]           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ TabularForecastMod… │ (None, 28)        │     77,934 │ tabular_input[0]… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ raster_output_Y1    │ (None, 64, 64, 1) │          0 │ RasterForecastMo… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ raster_output_Y2    │ (None, 64, 64, 1) │          0 │ RasterForecastMo… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabularForecastY1   │ (None, 14)        │          0 │ TabularForecastM… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabularForecastY2   │ (None, 14)        │          0 │ TabularForecastM… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Year1Classifier     │ (None, 1)         │  9,218,764 │ raster_output_Y1… │
# │ (Functional)        │                   │            │ tabularForecastY… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Year2Classifier     │ (None, 1)         │  9,218,764 │ raster_output_Y2… │
# │ (Functional)        │                   │            │ tabularForecastY… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 19,402,920 (74.02 MB)
#  Trainable params: 19,402,920 (74.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.preprocessing import StandardScaler
featuresScaler = StandardScaler()
train_features = featuresScaler.fit_transform(train_features.reshape((-1,70)))
val_features   = featuresScaler.transform(val_features.reshape((-1,70)))
test_features   = featuresScaler.transform(test_features.reshape((-1,70)))

# %%
targetScaler = StandardScaler()
train_target_features = targetScaler.fit_transform(train_target_features.reshape((-1,28)))
val_target_features   = targetScaler.transform(val_target_features.reshape((-1,28)))
test_target_features   = targetScaler.transform(test_target_features.reshape((-1,28)))

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Input, Conv2DTranspose, Concatenate, BatchNormalization, UpSampling2D
from keras.layers import  Dropout, Activation
from keras.optimizers import Adam, SGD
# from tensorflow.keras.activations import LeakyReLU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import backend as K
from keras.utils import plot_model
import tensorflow as tf

# %%
model = forecastClassifierModel()

model.compile(
    optimizer = keras.optimizers.Nadam(learning_rate = 1e-5),
    loss={
        
        'raster_output_Y1': 'mse',           
        'raster_output_Y2': 'mse',           
        
        
        'tabularForecastY1': 'mae',          
        'tabularForecastY2': 'mae',          
        
        
        'Year1Classifier': 'binary_crossentropy', 
        'Year2Classifier': 'binary_crossentropy'
    },
    metrics={
        'raster_output_Y1': ['mae'],
        'tabularForecastY1': ['mse'],
        'Year1Classifier': ['accuracy'],

        'raster_output_Y2': ['mae'],
        'tabularForecastY2': ['mse'],
        'Year2Classifier': ['accuracy']
    },
    loss_weights={
        'raster_output_Y1': 1.0,
        'raster_output_Y2': 1.0,
        'tabularForecastY1': 1.0,
        'tabularForecastY2': 1.0,
        'Year1Classifier': 2.0,  
        'Year2Classifier': 2.0
    }
)
model_path = '/kaggle/working/ClassifierModelNadam.keras'
from tensorflow.keras.callbacks import *
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=1e-8, verbose=1),
    ModelCheckpoint(model_path, verbose=1, save_best_only=True)
]

with tf.device('/gpu:0'):
    results = model.fit((train_images, train_features),
                        (train_target_images[...,0], train_target_images[...,1],
                         train_target_features[:,:14], train_target_features[:,14:],
                         train_classes[:,0], train_classes[:,1]
                        ), 
                        batch_size=16, epochs=500, callbacks=callbacks,
                        validation_data=((val_images, val_features),
                        (val_target_images[...,0], val_target_images[...,1],
                         val_target_features[:,:14], val_target_features[:,14:],
                         val_classes[:,0], val_classes[:,1]
                        ))
                       )

model.load_weights(model_path)
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759068301.234586      59 service.cc:148] XLA service 0x7cbc78002fb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759068301.235021      59 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759068305.217845      59 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   3/159 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - Year1Classifier_accuracy: 0.8924 - Year1Classifier_loss: 0.3593 - Year2Classifier_accuracy: 0.8750 - Year2Classifier_loss: 0.3493 - loss: 2.5267 - raster_output_Y1_loss: 0.1200 - raster_output_Y1_mae: 0.1667 - raster_output_Y2_loss: 0.1605 - raster_output_Y2_mae: 0.1869 - tabularForecastY1_loss: 0.3889 - tabularForecastY1_mse: 0.3584 - tabularForecastY2_loss: 0.4402 - tabularForecastY2_mse: 0.5453
# I0000 00:00:1759068335.155215      59 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - Year1Classifier_accuracy: 0.9342 - Year1Classifier_loss: 0.2028 - Year2Classifier_accuracy: 0.9149 - Year2Classifier_loss: 0.2420 - loss: 1.8765 - raster_output_Y1_loss: 0.0983 - raster_output_Y1_mae: 0.1581 - raster_output_Y2_loss: 0.1527 - raster_output_Y2_mae: 0.1852 - tabularForecastY1_loss: 0.3422 - tabularForecastY1_mse: 0.3199 - tabularForecastY2_loss: 0.3936 - tabularForecastY2_mse: 0.4226
# Epoch 1: val_loss improved from inf to 1.85862, saving model to /kaggle/working/ClassifierModelNadam.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 132s 277ms/step - Year1Classifier_accuracy: 0.9343 - Year1Classifier_loss: 0.2027 - Year2Classifier_accuracy: 0.9149 - Year2Classifier_loss: 0.2419 - loss: 1.8760 - raster_output_Y1_loss: 0.0983 - raster_output_Y1_mae: 0.1581 - raster_output_Y2_loss: 0.1527 - raster_output_Y2_mae: 0.1852 - tabularForecastY1_loss: 0.3422 - tabularForecastY1_mse: 0.3201 - tabularForecastY2_loss: 0.3936 - tabularForecastY2_mse: 0.4227 - val_Year1Classifier_accuracy: 0.9366 - val_Year1Classifier_loss: 0.1913 - val_Year2Classifier_accuracy: 0.8955 - val_Year2Classifier_loss: 0.
- val_Year2Classifier_accuracy: 0.8955 - val_Year2Classifier_loss: 0.2724 - val_loss: 1.9244 - val_raster_output_Y1_loss: 0.1425 - val_raster_output_Y1_mae: 0.1807 - val_raster_output_Y2_loss: 0.2249 - val_raster_output_Y2_mae: 0.2185 - val_tabularForecastY1_loss: 0.2527 - val_tabularForecastY1_mse: 0.4159 - val_tabularForecastY2_loss: 0.3213 - val_tabularForecastY2_mse: 0.5111 - learning_rate: 1.0000e-08
# Epoch 16: early stopping

# %%
model.evaluate(
    (test_images, test_features),
    (
        test_target_images[...,0], test_target_images[...,1],
        test_target_features[:,:14], test_target_features[:,14:],
        test_classes[:,0], test_classes[:,1]
    )
)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 385ms/step - Year1Classifier_accuracy: 0.8935 - Year1Classifier_loss: 0.2905 - Year2Classifier_accuracy: 0.8819 - Year2Classifier_loss: 0.3437 - loss: 2.3548 - raster_output_Y1_loss: 0.1698 - raster_output_Y1_mae: 0.2046 - raster_output_Y2_loss: 0.2784 - raster_output_Y2_mae: 0.2547 - tabularForecastY1_loss: 0.2779 - tabularForecastY1_mse: 0.3167 - tabularForecastY2_loss: 0.3602 - tabularForecastY2_mse: 0.5129
# [2.3800570964813232,
#  0.16062402725219727,
#  0.2626945376396179,
#  0.26485776901245117,
#  0.33878397941589355,
#  0.3032253384590149,
#  0.3729500472545624,
#  0.9011857509613037,
#  0.8774703741073608,
#  0.19599272310733795,
#  0.24256962537765503,
#  0.31695520877838135,
#  0.48450255393981934]

# %%
model = forecastClassifierModel()
from tensorflow.keras.callbacks import *

model.compile(
    optimizer = keras.optimizers.Adam(learning_rate = 1e-5),
    loss={
        
        'raster_output_Y1': 'mse',           
        'raster_output_Y2': 'mse',           
        
        
        'tabularForecastY1': 'mae',          
        'tabularForecastY2': 'mae',          
        
        
        'Year1Classifier': 'binary_crossentropy', 
        'Year2Classifier': 'binary_crossentropy'
    },
    metrics={
        'raster_output_Y1': ['mae'],
        'tabularForecastY1': ['mse'],
        'Year1Classifier': ['accuracy'],

        'raster_output_Y2': ['mae'],
        'tabularForecastY2': ['mse'],
        'Year2Classifier': ['accuracy']
    },
    loss_weights={
        'raster_output_Y1': 1.0,
        'raster_output_Y2': 1.0,
        'tabularForecastY1': 1.0,
        'tabularForecastY2': 1.0,
        'Year1Classifier': 2.0,  
        'Year2Classifier': 2.0
    }
)

model_path = '/kaggle/working/ClassifierModelAdam.keras'
from tensorflow.keras.callbacks import *
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=1e-8, verbose=1),
    ModelCheckpoint(model_path, verbose=1, save_best_only=True)
]

with tf.device('/gpu:0'):
    results = model.fit((train_images, train_features),
                        (train_target_images[...,0], train_target_images[...,1],
                         train_target_features[:,:14], train_target_features[:,14:],
                         train_classes[:,0], train_classes[:,1]
                        ), 
                        batch_size=16, epochs=500, callbacks=callbacks,
                        validation_data=((val_images, val_features),
                        (val_target_images[...,0], val_target_images[...,1],
                         val_target_features[:,:14], val_target_features[:,14:],
                         val_classes[:,0], val_classes[:,1]
                        ))
                       )

model.load_weights(model_path)
# Out:
# Epoch 1/500
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
- val_Year2Classifier_accuracy: 0.8955 - val_Year2Classifier_loss: 0.2880 - val_loss: 1.9617 - val_raster_output_Y1_loss: 0.1425 - val_raster_output_Y1_mae: 0.1809 - val_raster_output_Y2_loss: 0.2266 - val_raster_output_Y2_mae: 0.2207 - val_tabularForecastY1_loss: 0.2510 - val_tabularForecastY1_mse: 0.4187 - val_tabularForecastY2_loss: 0.3199 - val_tabularForecastY2_mse: 0.5149 - learning_rate: 1.0000e-08
# Epoch 13: early stopping

# %%
model.evaluate(
    (test_images, test_features),
    (
        test_target_images[...,0], test_target_images[...,1],
        test_target_features[:,:14], test_target_features[:,14:],
        test_classes[:,0], test_classes[:,1]
    )
)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - Year1Classifier_accuracy: 0.8935 - Year1Classifier_loss: 0.3256 - Year2Classifier_accuracy: 0.8799 - Year2Classifier_loss: 0.3635 - loss: 2.4677 - raster_output_Y1_loss: 0.1711 - raster_output_Y1_mae: 0.2053 - raster_output_Y2_loss: 0.2821 - raster_output_Y2_mae: 0.2580 - tabularForecastY1_loss: 0.2772 - tabularForecastY1_mse: 0.3206 - tabularForecastY2_loss: 0.3590 - tabularForecastY2_mse: 0.5193
# [2.4739086627960205,
#  0.16189494729042053,
#  0.2661075294017792,
#  0.2637655436992645,
#  0.33750244975090027,
#  0.3317262828350067,
#  0.3898720443248749,
#  0.9011857509613037,
#  0.8774703741073608,
#  0.19653719663619995,
#  0.2455853819847107,
#  0.3203604817390442,
#  0.489795982837677]

# %%
from tensorflow.keras.callbacks import *
model = forecastClassifierModel()

model.compile(
    optimizer = keras.optimizers.SGD(learning_rate = 1e-5),
    loss={
        
        'raster_output_Y1': 'mse',           
        'raster_output_Y2': 'mse',           
        
        
        'tabularForecastY1': 'mae',          
        'tabularForecastY2': 'mae',          
        
        
        'Year1Classifier': 'binary_crossentropy', 
        'Year2Classifier': 'binary_crossentropy'
    },
    metrics={
        'raster_output_Y1': ['mae'],
        'tabularForecastY1': ['mse'],
        'Year1Classifier': ['accuracy'],

        'raster_output_Y2': ['mae'],
        'tabularForecastY2': ['mse'],
        'Year2Classifier': ['accuracy']
    },
    loss_weights={
        'raster_output_Y1': 1.0,
        'raster_output_Y2': 1.0,
        'tabularForecastY1': 1.0,
        'tabularForecastY2': 1.0,
        'Year1Classifier': 2.0,  
        'Year2Classifier': 2.0
    }
)
model_path = '/kaggle/working/ClassifierModelSGD.keras'
from tensorflow.keras.callbacks import *
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=1e-8, verbose=1),
    ModelCheckpoint(model_path, verbose=1, save_best_only=True)
]

with tf.device('/gpu:0'):
    results = model.fit((train_images, train_features),
                        (train_target_images[...,0], train_target_images[...,1],
                         train_target_features[:,:14], train_target_features[:,14:],
                         train_classes[:,0], train_classes[:,1]
                        ), 
                        batch_size=16, epochs=500, callbacks=callbacks,
                        validation_data=((val_images, val_features),
                        (val_target_images[...,0], val_target_images[...,1],
                         val_target_features[:,:14], val_target_features[:,14:],
                         val_classes[:,0], val_classes[:,1]
                        ))
                       )

model.load_weights(model_path)
# Out:
# Epoch 1/500
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step

# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - Year1Classifier_accuracy: 0.8935 - Year1Classifier_loss: 0.3241 - Year2Classifier_accuracy: 0.8799 - Year2Classifier_loss: 0.3641 - loss: 2.4643 - raster_output_Y1_loss: 0.1704 - raster_output_Y1_mae: 0.2056 - raster_output_Y2_loss: 0.2816 - raster_output_Y2_mae: 0.2577 - tabularForecastY1_loss: 0.2768 - tabularForecastY1_mse: 0.3206 - tabularForecastY2_loss: 0.3588 - tabularForecastY2_mse: 0.5194
# [2.4701807498931885,
#  0.16121259331703186,
#  0.26553308963775635,
#  0.2634090185165405,
#  0.33727309107780457,
#  0.33101439476013184,
#  0.38963213562965393,
#  0.9011857509613037,
#  0.8774703741073608,
#  0.19692742824554443,
#  0.24530312418937683,
#  0.3203490674495697,
#  0.48993000388145447]

# %%
from tensorflow.keras.callbacks import *
model = forecastClassifierModel()


model.compile(
    optimizer = keras.optimizers.RMSprop(learning_rate = 1e-5),
    loss={
        
        'raster_output_Y1': 'mse',           
        'raster_output_Y2': 'mse',           
        
        'tabularForecastY1': 'mae',          
        'tabularForecastY2': 'mae',          
        
        'Year1Classifier': 'binary_crossentropy', 
        'Year2Classifier': 'binary_crossentropy'
    },
    metrics={
        'raster_output_Y1': ['mae'],
        'tabularForecastY1': ['mse'],
        'Year1Classifier': ['accuracy'],

        'raster_output_Y2': ['mae'],
        'tabularForecastY2': ['mse'],
        'Year2Classifier': ['accuracy']
    },
    loss_weights={
        'raster_output_Y1': 1.0,
        'raster_output_Y2': 1.0,
        'tabularForecastY1': 1.0,
        'tabularForecastY2': 1.0,
        'Year1Classifier': 2.0,  
        'Year2Classifier': 2.0
    }
)

model_path = '/kaggle/working/ClassifierModelRMSprop.keras'
from tensorflow.keras.callbacks import *
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=1e-8, verbose=1),
    ModelCheckpoint(model_path, verbose=1, save_best_only=True)
]

with tf.device('/gpu:0'):
    results = model.fit((train_images, train_features),
                        (train_target_images[...,0], train_target_images[...,1],
                         train_target_features[:,:14], train_target_features[:,14:],
                         train_classes[:,0], train_classes[:,1]
                        ), 
                        batch_size=16, epochs=500, callbacks=callbacks,
                        validation_data=((val_images, val_features),
                        (val_target_images[...,0], val_target_images[...,1],
                         val_target_features[:,:14], val_target_features[:,14:],
                         val_classes[:,0], val_classes[:,1]
                        ))
                       )

model.load_weights(model_path)
# Out:
# Epoch 1/500
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - Year1Classifier_accuracy: 0.9767 - Year1Classifier_loss: 0.0944 - Year2Classifier_accuracy: 0.9737 - Year2Classifier_loss: 0.0988 - loss: 1.3560 - raster_output_Y1_loss: 0.0952 - raster_output_Y1_mae: 0.1550 - raster_output_Y2_loss: 0.1448 - raster_output_Y2_mae: 0.1838 - tabularForecastY1_loss: 0.3382 - tabularForecastY1_mse: 0.3458 - tabularForecastY2_loss: 0.3912 - tabularForecastY2_mse: 0.4545
# Epoch 1: val_loss improved from inf to 1.98381, saving model to /kaggle/working/ClassifierModelRMSprop.keras
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step
.2466 - val_Year2Classifier_accuracy: 0.9030 - val_Year2Classifier_loss: 0.2989 - val_loss: 2.0149 - val_raster_output_Y1_loss: 0.1430 - val_raster_output_Y1_mae: 0.1818 - val_raster_output_Y2_loss: 0.2273 - val_raster_output_Y2_mae: 0.2228 - val_tabularForecastY1_loss: 0.2492 - val_tabularForecastY1_mse: 0.4219 - val_tabularForecastY2_loss: 0.3185 - val_tabularForecastY2_mse: 0.5186 - learning_rate: 1.0000e-07
# Epoch 14/500
# 157/159 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - Year1Classifier_accuracy: 0.9816 - Year1Classifier_loss: 0.0654 - Year2Classifier_accuracy: 0.9859 - Year2Classifier_loss: 0.0601 - loss: 1.2034 - raster_output_Y1_loss: 0.0922 - raster_output_Y1_mae: 0.1529 - raster_output_Y2_loss: 0.1485 - raster_output_Y2_mae: 0.1870 - tabularForecastY1_loss: 0.3280 - tabularForecastY1_mse: 0.3351 - tabularForecastY2_loss: 0.3838 - tabularForecastY2_mse: 0.4356
# Epoch 14: val_loss did not improve from 1.94934
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - Year1Classifier_accuracy: 0.9817 - Year1Classifier_loss: 0.0653 - Year2Classifier_accuracy: 0.9860 - Year2Classifier_loss: 0.0601 - loss: 1.2033 - raster_output_Y1_loss: 0.0922 - raster_output_Y1_mae: 0.1530 - raster_output_Y2_loss: 0.1485 - raster_output_Y2_mae: 0.1871 - tabularForecastY1_loss: 0.3281 - tabularForecastY1_mse: 0.3354 - tabularForecastY2_loss: 0.3838 - tabularForecastY2_mse: 0.4358 - val_Year1Classifier_accuracy: 0.9216 - val_Year1Classifier_loss: 0.2466 - val_Year2Classifier_accuracy: 0.9030 - val_Year2Classifier_loss: 0.2989 - val_loss: 2.0149 - val_raster_output_Y1_loss: 0.1430 - val_raster_output_Y1_mae: 0.1818 - val_raster_output_Y2_loss: 0.2273 - val_raster_output_Y2_mae: 0.2228 - val_tabularForecastY1_loss: 0.2492 - val_tabularForecastY1_mse: 0.4219 - val_tabularForecastY2_loss: 0.3185 - val_tabularForecastY2_mse: 0.5186 - learning_rate: 1.0000e-08
# Epoch 14: early stopping

# %%
model.evaluate(
    (test_images, test_features),
    (
        test_target_images[...,0], test_target_images[...,1],
        test_target_features[:,:14], test_target_features[:,14:],
        test_classes[:,0], test_classes[:,1]
    )
)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - Year1Classifier_accuracy: 0.8900 - Year1Classifier_loss: 0.3483 - Year2Classifier_accuracy: 0.8799 - Year2Classifier_loss: 0.3898 - loss: 2.5647 - raster_output_Y1_loss: 0.1715 - raster_output_Y1_mae: 0.2066 - raster_output_Y2_loss: 0.2851 - raster_output_Y2_mae: 0.2608 - tabularForecastY1_loss: 0.2743 - tabularForecastY1_mse: 0.3243 - tabularForecastY2_loss: 0.3572 - tabularForecastY2_mse: 0.5268
# [2.5597758293151855,
#  0.16222046315670013,
#  0.26864543557167053,
#  0.2597993314266205,
#  0.33498576283454895,
#  0.35611918568611145,
#  0.40992048382759094,
#  0.8972331881523132,
#  0.8774703741073608,
#  0.19778981804847717,
#  0.24818158149719238,
#  0.32331857085227966,
#  0.49568238854408264]
